# %%
# Import the dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy 
import requests
import time
from datetime import datetime

from config import weather_api_key

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_describ = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_describ})
                          #"Date": city_date

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | alofi
# Processing Record 2 of Set 1 | limbang
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | la ronge
# Processing Record 6 of Set 1 | geraldton
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | aguimes
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | yulara
# Processing Record 12 of Set 1 | kirakira
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | mahebourg
# Processing Record 17 of Set 1 | fuxin
# Processing Record 18 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 1 | los llanos de aridane
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | lensk
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | junin
# Processing Record 28 of Set 1 | vanino
# Processing Record 29 of Set 1 | namibe
# Processing Record 30 of Set 1 | pisco
# Processing Record 31 of Set 1 | maumere
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | tuktoyaktuk
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | san patricio
# Processing Record 36 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | saint-augustin
# Processing Record 39 of Set 1 | warwick
# Processing Record 40 of Set 1 | ahipara
# Processing Record 41 of Set 1 | itarema
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | amapa
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | khatanga
# Processing Record 47 of Set 1 | ponta do sol
# Processing Record 48 of Set 1 | tan an
# Processing Record 49 of Set 1 | bubaque
# Processing Record 50 of Set 1 | margate
# Processing Record 1 of Set 2 | pevek
# Processing Record 2 of Set 2 | poum
# Processing Record 3 of Set 2 | nhulunbuy
# Processing Record 4 of Set 2 | skjervoy
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | andselv
# City not found. Skipping...
# Processing Record 7 of Set 2 | paita
# Processing Record 8 of Set 2 | udachnyy
# Processing Record 9 of Set 2 | faya
# Processing Record 10 of Set 2 | beba
# Processing Record 11 of Set 2 | azul
# Processing Record 12 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 2 | puerto escondido
# Processing Record 14 of Set 2 | manawar
# Processing Record 15 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 2 | verkhnevilyuysk
# Processing Record 17 of Set 2 | saint-philippe
# Processing Record 18 of Set 2 | mikhaylovka
# Processing Record 19 of Set 2 | loubomo
# Processing Record 20 of Set 2 | esperance
# Processing Record 21 of Set 2 | arraial do cabo
# Processing Record 22 of Set 2 | sur
# Processing Record 23 of Set 2 | norman wells
# Processing Record 24 of Set 2 | luena
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | ascension
# Processing Record 27 of Set 2 | bluff
# Processing Record 28 of Set 2 | labuhan
# Processing Record 29 of Set 2 | yar-sale
# Processing Record 30 of Set 2 | sarauli
# Processing Record 31 of Set 2 | yeppoon
# Processing Record 32 of Set 2 | mayskiy
# Processing Record 33 of Set 2 | ocho rios
# Processing Record 34 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 2 | bambous virieux
# Processing Record 36 of Set 2 | provideniya
# Processing Record 37 of Set 2 | hasaki
# Processing Record 38 of Set 2 | bulgan
# Processing Record 39 of Set 2 | nyurba
# Processing Record 40 of Set 2 | balaipungut
# Processing Record 41 of Set 2 | itaquyry
# Processing Record 42 of Set 2 | port said
# Processing Record 43 of Set 2 | upington
# Processing Record 44 of Set 2 | gardner
# Processing Record 45 of Set 2 | mahibadhoo
# Processing Record 46 of Set 2 | talara
# Processing Record 47 of Set 2 | mount gambier
# Processing Record 48 of Set 2 | bethel
# Processing Record 49 of Set 2 | tymovskoye
# Processing Record 50 of Set 2 | piacabucu
# Processing Record 1 of Set 3 | campoverde
# Processing Record 2 of Set 3 | chokurdakh
# Processing Record 3 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 3 | lebu
# Processing Record 5 of Set 3 | liverpool
# Processing Record 6 of Set 3 | le mars
# Processing Record 7 of Set 3 | quelimane
# Processing Record 8 of Set 3 | berlevag
# Processing Record 9 of Set 3 | nouadhibou
# Processing Record 10 of Set 3 | jacareacanga
# Processing Record 11 of Set 3 | vao
# Processing Record 12 of Set 3 | mawlaik
# Processing Record 13 of Set 3 | ossora
# Processing Record 14 of Set 3 | stornoway
# Processing Record 15 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 3 | portland
# Processing Record 17 of Set 3 | chara
# Processing Record 18 of Set 3 | vanimo
# Processing Record 19 of Set 3 | antofagasta
# Processing Record 20 of Set 3 | placido de castro
# Processing Record 21 of Set 3 | carutapera
# Processing Record 22 of Set 3 | ancud
# Processing Record 23 of Set 3 | lyubech
# Processing Record 24 of Set 3 | lavrentiya
# Processing Record 25 of Set 3 | tutoia
# Processing Record 26 of Set 3 | hithadhoo
# Processing Record 27 of Set 3 | bintulu
# Processing Record 28 of Set 3 | concepcion
# Processing Record 29 of Set 3 | hendek
# Processing Record 30 of Set 3 | dikson
# Processing Record 31 of Set 3 | rehoboth
# Processing Record 32 of Set 3 | hervey bay
# Processing Record 33 of Set 3 | cabo san lucas
# Processing Record 34 of Set 3 | grindavik
# Processing Record 35 of Set 3 | linxia
# Processing Record 36 of Set 3 | baculin
# Processing Record 37 of Set 3 | katsuura
# Processing Record 38 of Set 3 | lata
# Processing Record 39 of Set 3 | qaanaaq
# Processing Record 40 of Set 3 | iqaluit
# Processing Record 41 of Set 3 | nikolskoye
# Processing Record 42 of Set 3 | east london
# Processing Record 43 of Set 3 | juneau
# Processing Record 44 of Set 3 | chiang khong
# Processing Record 45 of Set 3 | muros
# Processing Record 46 of Set 3 | ramshir
# Processing Record 47 of Set 3 | birao
# Processing Record 48 of Set 3 | ardalstangen
# Processing Record 49 of Set 3 | asau
# Processing Record 50 of Set 3 | rocha
# Processing Record 1 of Set 4 | kruisfontein
# Processing Record 2 of Set 4 | lantawan
# Processing Record 3 of Set 4 | emerald
# Processing Record 4 of Set 4 | klaksvik
# Processing Record 5 of Set 4 | thompson
# Processing Record 6 of Set 4 | phan thiet
# Processing Record 7 of Set 4 | langsa
# Processing Record 8 of Set 4 | kavieng
# Processing Record 9 of Set 4 | baykit
# Processing Record 10 of Set 4 | waingapu
# Processing Record 11 of Set 4 | manturovo
# Processing Record 12 of Set 4 | camacari
# Processing Record 13 of Set 4 | bilma
# Processing Record 14 of Set 4 | kikwit
# Processing Record 15 of Set 4 | mattru
# Processing Record 16 of Set 4 | new norfolk
# Processing Record 17 of Set 4 | upernavik
# Processing Record 18 of Set 4 | kinsale
# Processing Record 19 of Set 4 | hambantota
# Processing Record 20 of Set 4 | kaitangata
# Processing Record 21 of Set 4 | luau
# Processing Record 22 of Set 4 | cayenne
# Processing Record 23 of Set 4 | puerto narino
# Processing Record 24 of Set 4 | rovaniemi
# Processing Record 25 of Set 4 | kalmunai
# Processing Record 26 of Set 4 | rio grande
# Processing Record 27 of Set 4 | sao miguel do araguaia
# Processing Record 28 of Set 4 | tasiilaq
# Processing Record 29 of Set 4 | girau do ponciano
# Processing Record 30 of Set 4 | esso
# Processing Record 31 of Set 4 | ugoofaaru
# Processing Record 32 of Set 4 | maceio
# Processing Record 33 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 4 | luderitz
# Processing Record 35 of Set 4 | komsomolskiy
# Processing Record 36 of Set 4 | dickinson
# Processing Record 37 of Set 4 | bambanglipuro
# Processing Record 38 of Set 4 | mount darwin
# Processing Record 39 of Set 4 | high level
# Processing Record 40 of Set 4 | junagadh
# Processing Record 41 of Set 4 | cidreira
# Processing Record 42 of Set 4 | isiolo
# Processing Record 43 of Set 4 | powell
# Processing Record 44 of Set 4 | morant bay
# Processing Record 45 of Set 4 | mosquera
# Processing Record 46 of Set 4 | ribeira grande
# Processing Record 47 of Set 4 | ilhabela
# Processing Record 48 of Set 4 | ape
# Processing Record 49 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 4 | haines junction
# Processing Record 1 of Set 5 | longyearbyen
# Processing Record 2 of Set 5 | talnakh
# Processing Record 3 of Set 5 | karamea
# City not found. Skipping...
# Processing Record 4 of Set 5 | cockburn town
# Processing Record 5 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 5 | ambilobe
# Processing Record 7 of Set 5 | srednekolymsk
# Processing Record 8 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 9 of Set 5 | solnechnyy
# Processing Record 10 of Set 5 | tiksi
# Processing Record 11 of Set 5 | karratha
# Processing Record 12 of Set 5 | cabedelo
# Processing Record 13 of Set 5 | saint-francois
# Processing Record 14 of Set 5 | vestmannaeyjar
# Processing Record 15 of Set 5 | tshane
# Processing Record 16 of Set 5 | port elizabeth
# Processing Record 17 of Set 5 | sitka
# Processing Record 18 of Set 5 | mar del plata
# Processing Record 19 of Set 5 | shache
# Processing Record 20 of Set 5 | sarankhola
# Processing Record 21 of Set 5 | homer
# Processing Record 22 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 5 | omsukchan
# Processing Record 24 of Set 5 | palkonda
# Processing Record 25 of Set 5 | vardo
# Processing Record 26 of Set 5 | mareeba
# Processing Record 27 of Set 5 | carnarvon
# Processing Record 28 of Set 5 | san borja
# Processing Record 29 of Set 5 | shaowu
# Processing Record 30 of Set 5 | torbay
# Processing Record 31 of Set 5 | port hardy
# Processing Record 32 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 33 of Set 5 | rawson
# Processing Record 34 of Set 5 | mitsamiouli
# Processing Record 35 of Set 5 | pekalongan
# Processing Record 36 of Set 5 | hobyo
# Processing Record 37 of Set 5 | pasighat
# Processing Record 38 of Set 5 | priargunsk
# Processing Record 39 of Set 5 | nirmal
# Processing Record 40 of Set 5 | sinnamary
# Processing Record 41 of Set 5 | mazamari
# Processing Record 42 of Set 5 | lowestoft
# Processing Record 43 of Set 5 | juli
# Processing Record 44 of Set 5 | saskylakh
# Processing Record 45 of Set 5 | barwaha
# City not found. Skipping...
# Processing Record 46 of Set 5 | samarai
# Processing Record 47 of Set 5 | eirunepe
# Processing Record 48 of Set 5 | fare
# Processing Record 49 of Set 5 | edinburg
# Processing Record 50 of Set 5 | maridi
# Processing Record 1 of Set 6 | byron bay
# Processing Record 2 of Set 6 | mamlyutka
# Processing Record 3 of Set 6 | pitkyaranta
# Processing Record 4 of Set 6 | calvinia
# Processing Record 5 of Set 6 | kuala terengganu
# Processing Record 6 of Set 6 | bilibino
# Processing Record 7 of Set 6 | latung
# Processing Record 8 of Set 6 | chuy
# Processing Record 9 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 6 | severo-kurilsk
# Processing Record 11 of Set 6 | cotonou
# Processing Record 12 of Set 6 | la palma
# Processing Record 13 of Set 6 | progreso
# Processing Record 14 of Set 6 | kodiak
# Processing Record 15 of Set 6 | bathsheba
# Processing Record 16 of Set 6 | flinders
# Processing Record 17 of Set 6 | souillac
# Processing Record 18 of Set 6 | kwinana
# Processing Record 19 of Set 6 | secunda
# Processing Record 20 of Set 6 | taree
# Processing Record 21 of Set 6 | wanning
# Processing Record 22 of Set 6 | bac lieu
# Processing Record 23 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 24 of Set 6 | coihaique
# Processing Record 25 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 6 | chapais
# Processing Record 27 of Set 6 | manzil salim
# Processing Record 28 of Set 6 | gayny
# Processing Record 29 of Set 6 | quesnel
# Processing Record 30 of Set 6 | banjar
# Processing Record 31 of Set 6 | lagoa
# Processing Record 32 of Set 6 | mayo
# Processing Record 33 of Set 6 | ketchikan
# Processing Record 34 of Set 6 | sarangani
# Processing Record 35 of Set 6 | pathein
# Processing Record 36 of Set 6 | puerto ayora
# Processing Record 37 of Set 6 | paamiut
# Processing Record 38 of Set 6 | anchorage
# Processing Record 39 of Set 6 | taylorville
# Processing Record 40 of Set 6 | acarau
# Processing Record 41 of Set 6 | wilmington
# Processing Record 42 of Set 6 | belmonte
# Processing Record 43 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 44 of Set 6 | caceres
# Processing Record 45 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 46 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 6 | beringovskiy
# Processing Record 48 of Set 6 | pitimbu
# Processing Record 49 of Set 6 | salem
# Processing Record 50 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 7 | yumen
# Processing Record 2 of Set 7 | aviles
# Processing Record 3 of Set 7 | ayios ioannis
# Processing Record 4 of Set 7 | deputatskiy
# Processing Record 5 of Set 7 | lorengau
# Processing Record 6 of Set 7 | mochudi
# Processing Record 7 of Set 7 | najran
# Processing Record 8 of Set 7 | dharur
# Processing Record 9 of Set 7 | havelock
# Processing Record 10 of Set 7 | ekibastuz
# Processing Record 11 of Set 7 | vila franca do campo
# Processing Record 12 of Set 7 | gao
# Processing Record 13 of Set 7 | dukat
# Processing Record 14 of Set 7 | boddam
# Processing Record 15 of Set 7 | omagh
# Processing Record 16 of Set 7 | bonfim
# Processing Record 17 of Set 7 | linchuan
# City not found. Skipping...
# Processing Record 18 of Set 7 | nizhniy tsasuchey
# Processing Record 19 of Set 7 | ndjole
# Processing Record 20 of Set 7 | itaituba
# Processing Record 21 of Set 7 | hvide sande
# Processing Record 22 of Set 7 | carauari
# Processing Record 23 of Set 7 | celestun
# Processing Record 24 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 7 | kichera
# Processing Record 26 of Set 7 | mlonggo
# Processing Record 27 of Set 7 | buala
# Processing Record 28 of Set 7 | mahenge
# Processing Record 29 of Set 7 | mitu
# Processing Record 30 of Set 7 | tilichiki
# Processing Record 31 of Set 7 | ribas do rio pardo
# Processing Record 32 of Set 7 | victoria
# Processing Record 33 of Set 7 | sabancuy
# Processing Record 34 of Set 7 | korla
# Processing Record 35 of Set 7 | husavik
# Processing Record 36 of Set 7 | ostersund
# Processing Record 37 of Set 7 | nabire
# Processing Record 38 of Set 7 | khorixas
# Processing Record 39 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 7 | neepawa
# Processing Record 41 of Set 7 | pitanga
# Processing Record 42 of Set 7 | college
# Processing Record 43 of Set 7 | aksarka
# Processing Record 44 of Set 7 | victor harbor
# Processing Record 45 of Set 7 | habra
# Processing Record 46 of Set 7 | bengkulu
# Processing Record 47 of Set 7 | kununurra
# Processing Record 48 of Set 7 | adrar
# Processing Record 49 of Set 7 | hualmay
# Processing Record 50 of Set 7 | bogovarovo
# Processing Record 1 of Set 8 | tateyama
# Processing Record 2 of Set 8 | abu samrah
# Processing Record 3 of Set 8 | thinadhoo
# Processing Record 4 of Set 8 | sao filipe
# Processing Record 5 of Set 8 | lianran
# Processing Record 6 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 7 of Set 8 | tampilisan
# Processing Record 8 of Set 8 | pronsk
# Processing Record 9 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 8 | carballo
# Processing Record 11 of Set 8 | ishigaki
# Processing Record 12 of Set 8 | iskateley
# Processing Record 13 of Set 8 | zhezkazgan
# Processing Record 14 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 15 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 8 | leshukonskoye
# Processing Record 17 of Set 8 | tezu
# Processing Record 18 of Set 8 | senekal
# Processing Record 19 of Set 8 | gat
# Processing Record 20 of Set 8 | the valley
# Processing Record 21 of Set 8 | san cristobal
# Processing Record 22 of Set 8 | qiongshan
# Processing Record 23 of Set 8 | ericeira
# Processing Record 24 of Set 8 | fortuna
# Processing Record 25 of Set 8 | tura
# Processing Record 26 of Set 8 | manggar
# Processing Record 27 of Set 8 | faanui
# Processing Record 28 of Set 8 | crestview
# Processing Record 29 of Set 8 | lompoc
# Processing Record 30 of Set 8 | saldanha
# Processing Record 31 of Set 8 | shelburne
# Processing Record 32 of Set 8 | georgetown
# Processing Record 33 of Set 8 | zelenogradsk
# Processing Record 34 of Set 8 | okha
# Processing Record 35 of Set 8 | salym
# Processing Record 36 of Set 8 | verkhoyansk
# Processing Record 37 of Set 8 | anderson
# Processing Record 38 of Set 8 | yamada
# Processing Record 39 of Set 8 | port townsend
# Processing Record 40 of Set 8 | roald
# Processing Record 41 of Set 8 | glace bay
# Processing Record 42 of Set 8 | batticaloa
# Processing Record 43 of Set 8 | airai
# Processing Record 44 of Set 8 | afua
# Processing Record 45 of Set 8 | kytlym
# City not found. Skipping...
# Processing Record 46 of Set 8 | dolores
# Processing Record 47 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 48 of Set 8 | cherskiy
# Processing Record 49 of Set 8 | yakima
# Processing Record 50 of Set 8 | pavlodar
# Processing Record 1 of Set 9 | olafsvik
# Processing Record 2 of Set 9 | piney green
# Processing Record 3 of Set 9 | desaguadero
# Processing Record 4 of Set 9 | chilca
# Processing Record 5 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 9 | guerrero negro
# Processing Record 8 of Set 9 | nantucket
# Processing Record 9 of Set 9 | sechura
# Processing Record 10 of Set 9 | ilulissat
# Processing Record 11 of Set 9 | ojinaga
# Processing Record 12 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 13 of Set 9 | itoman
# Processing Record 14 of Set 9 | mecca
# Processing Record 15 of Set 9 | lazaro cardenas
# Processing Record 16 of Set 9 | muncar
# Processing Record 17 of Set 9 | pahrump
# Processing Record 18 of Set 9 | lumut
# Processing Record 19 of Set 9 | berdigestyakh
# Processing Record 20 of Set 9 | nanortalik
# Processing Record 21 of Set 9 | evensk
# Processing Record 22 of Set 9 | pascagoula
# Processing Record 23 of Set 9 | hamilton
# Processing Record 24 of Set 9 | rorvik
# Processing Record 25 of Set 9 | channel-port aux basques
# Processing Record 26 of Set 9 | trat
# Processing Record 27 of Set 9 | port moresby
# Processing Record 28 of Set 9 | clearwater
# Processing Record 29 of Set 9 | bafia
# Processing Record 30 of Set 9 | eyl
# Processing Record 31 of Set 9 | kanigoro
# Processing Record 32 of Set 9 | jilib
# Processing Record 33 of Set 9 | kathu
# Processing Record 34 of Set 9 | muli
# Processing Record 35 of Set 9 | palana
# Processing Record 36 of Set 9 | wladyslawowo
# Processing Record 37 of Set 9 | kurgunta
# Processing Record 38 of Set 9 | nome
# Processing Record 39 of Set 9 | hokitika
# Processing Record 40 of Set 9 | awjilah
# Processing Record 41 of Set 9 | matagami
# Processing Record 42 of Set 9 | chake chake
# Processing Record 43 of Set 9 | vega de alatorre
# Processing Record 44 of Set 9 | parrita
# Processing Record 45 of Set 9 | havoysund
# Processing Record 46 of Set 9 | san rafael del sur
# Processing Record 47 of Set 9 | manzhouli
# Processing Record 48 of Set 9 | mnogovershinnyy
# Processing Record 49 of Set 9 | birin
# Processing Record 50 of Set 9 | kosh-agach
# Processing Record 1 of Set 10 | kieta
# Processing Record 2 of Set 10 | kerteh
# City not found. Skipping...
# Processing Record 3 of Set 10 | afumati
# Processing Record 4 of Set 10 | oskemen
# Processing Record 5 of Set 10 | coahuayana
# Processing Record 6 of Set 10 | boma
# Processing Record 7 of Set 10 | diamantino
# Processing Record 8 of Set 10 | stamsund
# City not found. Skipping...
# Processing Record 9 of Set 10 | saint george
# Processing Record 10 of Set 10 | minab
# Processing Record 11 of Set 10 | port lincoln
# Processing Record 12 of Set 10 | leningradskiy
# Processing Record 13 of Set 10 | poya
# Processing Record 14 of Set 10 | wroclaw
# Processing Record 15 of Set 10 | mwene-ditu
# Processing Record 16 of Set 10 | ust-ilimsk
# Processing Record 17 of Set 10 | capitan bado
# Processing Record 18 of Set 10 | monroe
# Processing Record 19 of Set 10 | orahovac
# Processing Record 20 of Set 10 | shieli
# Processing Record 21 of Set 10 | touros
# Processing Record 22 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 10 | axixa do tocantins
# City not found. Skipping...
# Processing Record 24 of Set 10 | sochi
# Processing Record 25 of Set 10 | libreville
# Processing Record 26 of Set 10 | codrington
# Processing Record 27 of Set 10 | walvis bay
# Processing Record 28 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 10 | bara
# Processing Record 30 of Set 10 | riyadh
# Processing Record 31 of Set 10 | port hedland
# Processing Record 32 of Set 10 | half moon bay
# Processing Record 33 of Set 10 | shediac
# Processing Record 34 of Set 10 | tuatapere
# Processing Record 35 of Set 10 | tarbagatay
# Processing Record 36 of Set 10 | kautokeino
# Processing Record 37 of Set 10 | khromtau
# Processing Record 38 of Set 10 | atar
# Processing Record 39 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 40 of Set 10 | tautira
# Processing Record 41 of Set 10 | abu dhabi
# Processing Record 42 of Set 10 | comodoro rivadavia
# Processing Record 43 of Set 10 | fairbanks
# Processing Record 44 of Set 10 | lulea
# Processing Record 45 of Set 10 | saint-pierre
# Processing Record 46 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 10 | taveta
# Processing Record 48 of Set 10 | balkanabat
# Processing Record 49 of Set 10 | skarzysko-kamienna
# Processing Record 50 of Set 10 | kyren
# Processing Record 1 of Set 11 | quatre cocos
# Processing Record 2 of Set 11 | bayan
# Processing Record 3 of Set 11 | redlands
# Processing Record 4 of Set 11 | kavaratti
# Processing Record 5 of Set 11 | luba
# Processing Record 6 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 11 | umm lajj
# Processing Record 8 of Set 11 | puerto pinasco
# City not found. Skipping...
# Processing Record 9 of Set 11 | laguna
# Processing Record 10 of Set 11 | catuday
# Processing Record 11 of Set 11 | jiutai
# Processing Record 12 of Set 11 | haapiti
# Processing Record 13 of Set 11 | kisangani
# Processing Record 14 of Set 11 | manjacaze
# Processing Record 15 of Set 11 | sola
# Processing Record 16 of Set 11 | ranong
# Processing Record 17 of Set 11 | alwaye
# Processing Record 18 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 11 | el sauzal
# Processing Record 20 of Set 11 | zhanaozen
# Processing Record 21 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 22 of Set 11 | begoro
# Processing Record 23 of Set 11 | slantsy
# Processing Record 24 of Set 11 | aklavik
# Processing Record 25 of Set 11 | kupang
# Processing Record 26 of Set 11 | fort pierce
# Processing Record 27 of Set 11 | ostrovnoy
# Processing Record 28 of Set 11 | hvammstangi
# City not found. Skipping...
# Processing Record 29 of Set 11 | yiyang
# Processing Record 30 of Set 11 | rameswaram
# Processing Record 31 of Set 11 | roma
# Processing Record 32 of Set 11 | alice springs
# Processing Record 33 of Set 11 | lippstadt
# Processing Record 34 of Set 11 | morondava
# Processing Record 35 of Set 11 | merauke
# Processing Record 36 of Set 11 | surt
# Processing Record 37 of Set 11 | elko
# Processing Record 38 of Set 11 | higuey
# City not found. Skipping...
# Processing Record 39 of Set 11 | gorontalo
# Processing Record 40 of Set 11 | bereda
# Processing Record 41 of Set 11 | codajas
# Processing Record 42 of Set 11 | calama
# Processing Record 43 of Set 11 | kapit
# Processing Record 44 of Set 11 | jutai
# Processing Record 45 of Set 11 | concordia
# Processing Record 46 of Set 11 | wanlaweyn
# Processing Record 47 of Set 11 | oussouye
# Processing Record 48 of Set 11 | mehamn
# Processing Record 49 of Set 11 | cap malheureux
# Processing Record 50 of Set 11 | saint anthony
# Processing Record 1 of Set 12 | inyonga
# Processing Record 2 of Set 12 | javanrud
# Processing Record 3 of Set 12 | poienile de sub munte
# Processing Record 4 of Set 12 | marquette
# Processing Record 5 of Set 12 | irtyshskiy
# Processing Record 6 of Set 12 | marica
# Processing Record 7 of Set 12 | burnie
# Processing Record 8 of Set 12 | chunhuhub
# Processing Record 9 of Set 12 | damghan
# Processing Record 10 of Set 12 | qaqortoq
# Processing Record 11 of Set 12 | shenjiamen
# Processing Record 12 of Set 12 | jumla
# Processing Record 13 of Set 12 | manaus
# Processing Record 14 of Set 12 | chimbote
# Processing Record 15 of Set 12 | staraya toropa
# Processing Record 16 of Set 12 | opunake
# Processing Record 17 of Set 12 | egvekinot
# Processing Record 18 of Set 12 | mahuva
# Processing Record 19 of Set 12 | sungairaya
# Processing Record 20 of Set 12 | barentu
# Processing Record 21 of Set 12 | san ramon
# Processing Record 22 of Set 12 | kesan
# Processing Record 23 of Set 12 | west lafayette
# Processing Record 24 of Set 12 | kodinsk
# Processing Record 25 of Set 12 | boda
# Processing Record 26 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 27 of Set 12 | panaba
# Processing Record 28 of Set 12 | kushima
# Processing Record 29 of Set 12 | beatrice
# Processing Record 30 of Set 12 | hofn
# Processing Record 31 of Set 12 | inhambane
# Processing Record 32 of Set 12 | ayia marina
# Processing Record 33 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 12 | itaqui
# Processing Record 35 of Set 12 | kungsbacka
# Processing Record 36 of Set 12 | gazojak
# Processing Record 37 of Set 12 | quibor
# Processing Record 38 of Set 12 | lufkin
# Processing Record 39 of Set 12 | murgab
# Processing Record 40 of Set 12 | middletown
# Processing Record 41 of Set 12 | xining
# Processing Record 42 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 43 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 45 of Set 12 | chegdomyn
# Processing Record 46 of Set 12 | northam
# Processing Record 47 of Set 12 | weihe
# Processing Record 48 of Set 12 | mouzakion
# City not found. Skipping...
# Processing Record 49 of Set 12 | gamba
# Processing Record 50 of Set 12 | kortkeros
# Processing Record 1 of Set 13 | okitipupa
# Processing Record 2 of Set 13 | rockingham
# Processing Record 3 of Set 13 | mende
# Processing Record 4 of Set 13 | kropotkin
# Processing Record 5 of Set 13 | along
# Processing Record 6 of Set 13 | manokwari
# Processing Record 7 of Set 13 | vakhtan
# Processing Record 8 of Set 13 | andenes
# Processing Record 9 of Set 13 | turukhansk
# Processing Record 10 of Set 13 | isangel
# Processing Record 11 of Set 13 | panchagarh
# Processing Record 12 of Set 13 | planeta rica
# Processing Record 13 of Set 13 | te anau
# Processing Record 14 of Set 13 | rujewa
# Processing Record 15 of Set 13 | toora-khem
# Processing Record 16 of Set 13 | nerchinskiy zavod
# Processing Record 17 of Set 13 | alegrete
# Processing Record 18 of Set 13 | great falls
# Processing Record 19 of Set 13 | hammerfest
# Processing Record 20 of Set 13 | nikolsk
# Processing Record 21 of Set 13 | kidal
# Processing Record 22 of Set 13 | kemijarvi
# Processing Record 23 of Set 13 | koratagere
# Processing Record 24 of Set 13 | vacaria
# Processing Record 25 of Set 13 | sumbe
# Processing Record 26 of Set 13 | puri
# Processing Record 27 of Set 13 | makat
# Processing Record 28 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 29 of Set 13 | kysyl-syr
# Processing Record 30 of Set 13 | muroto
# Processing Record 31 of Set 13 | brae
# Processing Record 32 of Set 13 | san quintin
# Processing Record 33 of Set 13 | konstantinovskoye
# Processing Record 34 of Set 13 | alappuzha
# Processing Record 35 of Set 13 | hodmezovasarhely
# Processing Record 36 of Set 13 | abeche
# Processing Record 37 of Set 13 | banos
# Processing Record 38 of Set 13 | jiroft
# City not found. Skipping...
# Processing Record 39 of Set 13 | vila
# Processing Record 40 of Set 13 | mayya
# Processing Record 41 of Set 13 | zhigansk
# Processing Record 42 of Set 13 | bontang
# Processing Record 43 of Set 13 | kailua
# Processing Record 44 of Set 13 | ternate
# Processing Record 45 of Set 13 | kuusamo
# Processing Record 46 of Set 13 | marsa matruh
# Processing Record 47 of Set 13 | vila velha
# Processing Record 48 of Set 13 | altay
# Processing Record 49 of Set 13 | tuy hoa
# Processing Record 50 of Set 13 | hanyang
# Processing Record 1 of Set 14 | scarborough
# Processing Record 2 of Set 14 | kanker
# Processing Record 3 of Set 14 | constitucion
# Processing Record 4 of Set 14 | kashan
# Processing Record 5 of Set 14 | lakhimpur
# Processing Record 6 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 14 | burica
# City not found. Skipping...
# Processing Record 8 of Set 14 | sao joao da barra
# Processing Record 9 of Set 14 | porto novo
# Processing Record 10 of Set 14 | sayyan
# Processing Record 11 of Set 14 | isla mujeres
# Processing Record 12 of Set 14 | clyde river
# Processing Record 13 of Set 14 | mora
# Processing Record 14 of Set 14 | batagay-alyta
# Processing Record 15 of Set 14 | henties bay
# Processing Record 16 of Set 14 | morwell
# Processing Record 17 of Set 14 | vostok
# Processing Record 18 of Set 14 | superior
# Processing Record 19 of Set 14 | taman
# Processing Record 20 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 21 of Set 14 | bonthe
# Processing Record 22 of Set 14 | vestmanna
# Processing Record 23 of Set 14 | ukiah
# Processing Record 24 of Set 14 | mariestad
# Processing Record 25 of Set 14 | cairns
# Processing Record 26 of Set 14 | oga
# Processing Record 27 of Set 14 | am timan
# Processing Record 28 of Set 14 | mogadishu
# Processing Record 29 of Set 14 | ust-maya
# Processing Record 30 of Set 14 | mjolby
# Processing Record 31 of Set 14 | bend
# Processing Record 32 of Set 14 | san jose
# Processing Record 33 of Set 14 | rajapur
# Processing Record 34 of Set 14 | sheopur
# Processing Record 35 of Set 14 | senneterre
# Processing Record 36 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 37 of Set 14 | ao luk
# City not found. Skipping...
# Processing Record 38 of Set 14 | sainte-anne-des-monts
# Processing Record 39 of Set 14 | cancun
# Processing Record 40 of Set 14 | ginir
# Processing Record 41 of Set 14 | arandas
# Processing Record 42 of Set 14 | el campo
# Processing Record 43 of Set 14 | iralaya
# Processing Record 44 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 14 | dwarka
# Processing Record 46 of Set 14 | karpathos
# Processing Record 47 of Set 14 | nueva gerona
# Processing Record 48 of Set 14 | marawi
# Processing Record 49 of Set 14 | uthal
# Processing Record 50 of Set 14 | huambo
# Processing Record 1 of Set 15 | narsaq
# Processing Record 2 of Set 15 | madimba
# Processing Record 3 of Set 15 | ikom
# Processing Record 4 of Set 15 | alta floresta
# Processing Record 5 of Set 15 | pokhara
# Processing Record 6 of Set 15 | goderich
# Processing Record 7 of Set 15 | port augusta
# Processing Record 8 of Set 15 | matamoros
# Processing Record 9 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 15 | salalah
# Processing Record 11 of Set 15 | yenagoa
# Processing Record 12 of Set 15 | reefton
# City not found. Skipping...
# Processing Record 13 of Set 15 | jiaojiang
# Processing Record 14 of Set 15 | mendahara
# City not found. Skipping...
# Processing Record 15 of Set 15 | san vicente
# Processing Record 16 of Set 15 | kamenka
# Processing Record 17 of Set 15 | canning
# Processing Record 18 of Set 15 | pampierstad
# Processing Record 19 of Set 15 | okhotsk
# Processing Record 20 of Set 15 | sovetskiy
# Processing Record 21 of Set 15 | coquimbo
# Processing Record 22 of Set 15 | lismore
# Processing Record 23 of Set 15 | yakeshi
# Processing Record 24 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 15 | mandalgovi
# Processing Record 26 of Set 15 | khani
# Processing Record 27 of Set 15 | iquique
# Processing Record 28 of Set 15 | kenai
# Processing Record 29 of Set 15 | ilek
# Processing Record 30 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 31 of Set 15 | bonavista
# Processing Record 32 of Set 15 | dunedin
# Processing Record 33 of Set 15 | gari
# Processing Record 34 of Set 15 | sulangan
# Processing Record 35 of Set 15 | san blas
# Processing Record 36 of Set 15 | ngunguru
# Processing Record 37 of Set 15 | arroyo
# Processing Record 38 of Set 15 | kuopio
# Processing Record 39 of Set 15 | puerto del rosario
# Processing Record 40 of Set 15 | nago
# Processing Record 41 of Set 15 | nandgaon
# Processing Record 42 of Set 15 | seymchan
# Processing Record 43 of Set 15 | kahului
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 675

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Alofi      NU -19.0595 -169.9187     71.49       100          40
# 1    Limbang      MY   4.7500  115.0000     80.71        98         100
# 2  Jamestown      US  42.0970  -79.2353     72.05        58          39
# 3   La Ronge      CA  55.1001 -105.2842     61.02        82          75
# 4  Geraldton      AU -28.7667  114.6000     57.61        82          75
#
#    Wind Speed Current Description
# 0        2.30    scattered clouds
# 1        2.10     overcast clouds
# 2        3.00    scattered clouds
# 3        5.75       broken clouds
# 4        5.75       broken clouds

# %%
city_data_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")
